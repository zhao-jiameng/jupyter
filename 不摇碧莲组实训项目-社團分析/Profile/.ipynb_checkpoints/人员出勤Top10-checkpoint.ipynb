# %% [markdown]
# # 人员出勤Top10
#
# > - 本模块主要使用清洗完的数据，进去去重
# > - 对同学来的次数进行count统计
# > - 并对Top10进行可视化展示

# %%
import pandas as pd
import numpy as np
import os
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_excel('../File/output/清洗完毕.xlsx')
data=data[['班级','姓名']]
data
# Out:
#              班级   姓名
# 0       大数据2201  景琳娜
# 1       大数据2201  寇佳梦
# 2       大数据2202  樊松林
# 3       大数据2202   郭瑾
# 4       大数据2202   雷蕾
# ...         ...  ...
# 1779  云计算中高2201   李锐
# 1780  云计算中高2201   卢飞
# 1781  云计算中高2201  秦韶斌
# 1782  云计算中高2201  安博闻
# 1783  云计算中高2201  杨树林
#
# [1784 rows x 2 columns]

# %% [markdown]
# ### Pandas版wordcount

# %%
word=pd.DataFrame(data[['班级','姓名']])
count=word.groupby(['班级','姓名']).apply(len)
count.sort_values(ascending=False, inplace=True)
wordcount=count.reset_index(name="count")
wordcount.to_excel('../File/output/社团人员.xlsx')

# %%
wordcount[wordcount['姓名']=='路震卫']
# Out:
#           班级   姓名  count
# 27  人工智能2201  路震卫     21

# %%
Top10=wordcount[:10]
Top10
# Out:
#          班级   姓名  count
# 0    数媒2201  王鹏宇     33
# 1    数媒2202   周漠     33
# 2   大数据2202  赵伟博     32
# 3    数媒2203  张晓芳     31
# 4   大数据2202  介丹阳     30
# 5    软件2201  王佳荣     30
# 6    数媒2202  董一洁     30
# 7   大数据2202   雷蕾     30
# 8  软件中高2201  申史良     29
# 9    数媒2201  荀书炜     28

# %%
from pyecharts import Bar
x = Top10['姓名']
y =Top10['count']
bar=Bar("出勤人员Top10","社團總體出勤人员Top10",title_color ="#2F4F4F")
title= '出勤次数'
bar.add(title,x,y,is_convert=True)
bar.render("../File/圖表/Top10条形图.html")
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="af44b541a1f64a32a69daca6a0b8fd8e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_af44b541a1f64a32a69daca6a0b8fd8e = echarts.init(document.getElementById('af44b541a1f64a32a69daca6a0b8fd8e'), 'light', {renderer: 'canvas'});
#
# var option_af44b541a1f64a32a69daca6a0b8fd8e = {
#     "title": [
#         {
#             "text": "\u51fa\u52e4\u4eba\u5458Top10",
#             "subtext": "\u793e\u5718\u7e3d\u9ad4\u51fa\u52e4\u4eba\u5458Top10",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#2F4F4F",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7122622,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u51fa\u52e4\u6b21\u6570",
#             "data": [
#                 33.0,
#                 33.0,
#                 32.0,
#                 31.0,
#                 30.0,
#                 30.0,
#                 30.0,
#                 30.0,
#                 29.0,
#                 28.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7122622
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u51fa\u52e4\u6b21\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u738b\u9e4f\u5b87",
#                 "\u5468\u6f20",
#                 "\u8d75\u4f1f\u535a",
#                 "\u5f20\u6653\u82b3",
#                 "\u4ecb\u4e39\u9633",
#                 "\u738b\u4f73\u8363",
#                 "\u8463\u4e00\u6d01",
#                 "\u96f7\u857e",
#                 "\u7533\u53f2\u826f",
#                 "\u8340\u4e66\u709c"
#             ]
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_af44b541a1f64a32a69daca6a0b8fd8e.setOption(option_af44b541a1f64a32a69daca6a0b8fd8e);
#
#     });
# </script>

# %%
from pyecharts import Pie
attr = Top10['班级']+Top10['姓名']
v1 = Top10['count']
pie = Pie("出勤人员Top10", title_pos='center')
pie.add(
    "",
    attr,
    v1,
    radius=[40, 75],
    label_text_color=None,
    is_label_show=True,
    is_more_utils=True,
    legend_orient="vertical",
    legend_pos="left",
    center=["65%", "55%"]
)
pie.render(path="../File/圖表/Top10饼状图.html")
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="270392922d5342b082021c39fc559ba0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_270392922d5342b082021c39fc559ba0 = echarts.init(document.getElementById('270392922d5342b082021c39fc559ba0'), 'light', {renderer: 'canvas'});
#
# var option_270392922d5342b082021c39fc559ba0 = {
#     "title": [
#         {
#             "text": "\u51fa\u52e4\u4eba\u5458Top10",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 6629210,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u6570\u5a922201\u738b\u9e4f\u5b87",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u6570\u5a922202\u5468\u6f20",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e2202\u8d75\u4f1f\u535a",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u6570\u5a922203\u5f20\u6653\u82b3",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e2202\u4ecb\u4e39\u9633",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u8f6f\u4ef62201\u738b\u4f73\u8363",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u6570\u5a922202\u8463\u4e00\u6d01",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e2202\u96f7\u857e",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u8f6f\u4ef6\u4e2d\u9ad82201\u7533\u53f2\u826f",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u6570\u5a922201\u8340\u4e66\u709c",
#                     "value": 28
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "65%%",
#                 "55%%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 6629210
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u5a922201\u738b\u9e4f\u5b87",
#                 "\u6570\u5a922202\u5468\u6f20",
#                 "\u5927\u6570\u636e2202\u8d75\u4f1f\u535a",
#                 "\u6570\u5a922203\u5f20\u6653\u82b3",
#                 "\u5927\u6570\u636e2202\u4ecb\u4e39\u9633",
#                 "\u8f6f\u4ef62201\u738b\u4f73\u8363",
#                 "\u6570\u5a922202\u8463\u4e00\u6d01",
#                 "\u5927\u6570\u636e2202\u96f7\u857e",
#                 "\u8f6f\u4ef6\u4e2d\u9ad82201\u7533\u53f2\u826f",
#                 "\u6570\u5a922201\u8340\u4e66\u709c"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "left",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_270392922d5342b082021c39fc559ba0.setOption(option_270392922d5342b082021c39fc559ba0);
#
#     });
# </script>

# %%
from pyecharts import WordCloud
name_list = Top10['姓名']
value_list = Top10['count']
wordcloud = WordCloud(width=800, height=500)
wordcloud.add("",name_list,value_list,word_size_range=[20,100])
wordcloud.render(path="../File/圖表/Top10词云图.html")
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="12572d5321214c118182f9840cda1e3f" style="width:800px;height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_12572d5321214c118182f9840cda1e3f = echarts.init(document.getElementById('12572d5321214c118182f9840cda1e3f'), 'light', {renderer: 'canvas'});
#
# var option_12572d5321214c118182f9840cda1e3f = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4860333,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u738b\u9e4f\u5b87",
#                     "value": 33,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(148,0,0)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5468\u6f20",
#                     "value": 33,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(13,23,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d75\u4f1f\u535a",
#                     "value": 32,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,67,37)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f20\u6653\u82b3",
#                     "value": 31,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,142,1)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ecb\u4e39\u9633",
#                     "value": 30,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(81,28,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u738b\u4f73\u8363",
#                     "value": 30,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(125,41,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8463\u4e00\u6d01",
#                     "value": 30,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,5,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u96f7\u857e",
#                     "value": 30,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,83,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7533\u53f2\u826f",
#                     "value": 29,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,21,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8340\u4e66\u709c",
#                     "value": 28,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(104,78,108)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_12572d5321214c118182f9840cda1e3f.setOption(option_12572d5321214c118182f9840cda1e3f);
#
#     });
# </script>
